# %% [markdown]
# # Direct Policy Search Reinforcement learning algorithm to train model to bring square in the image to its centre.
#
#
# Author: Pooja BELURE

# %%
import sys
import gym
import numpy as np

# %% [markdown]
# ## 1. Discrete Action Spaces
#
# We have implimented direct policy search algorithm using Black-Box optimization algoritms (evolutionary computation: CMA-ES, differential evolution: scipy.optimize). We are in the setting of model free approach.
#
# In order to efficienlty train our agent, we must:
# * Define your search space (policy space in which we are willing to search for)
# * Define your objective function: to assess a policy (Episode-based or step based)
# * Optimize the objective using balck-box optimizer (cma-es: use https://pypi.org/project/cma/ ; differential evolution: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.differential_evolution.html)
#
# Complete Agent Class:
# 1. `train` method: for optimizing the objective function to get optimal policy
# 2. `act` method: use optimal policy to output action for each state

# %%
import cma

class Agent:
    def __init__(self):
        """
        Init a new agent.
        """
        pass

    def train(self):
        """
        Learn your policy.

        Possible action: [0, 1, 2, 3]
        
        """
        # 1- Define state features [position, velocity]
        # 2- Define search space (to define a policy) -> policy: state (R^2) -> action
        # 3- Define objective function (for policy evaluation)
        # 4- Optimize the objective function
        # 5- Save optimal policy

        # This is an example
        def objective_function(W):
            total = 0
            env = gym.make("Pendulum-v0")
            env.seed(np.random.randint(1000))
            state = env.reset()
            done = False
            while not done:
                action = np.argmax(np.dot(state,W.reshape(2,2)))
                #print("------------>",action)
                state, reward, done, info = env.step(action)
                if reward==1:
                    print("------------>",state,action)
                total += -1
            return - total # loss
        
        self.policy_opt, _ = cma.fmin2(objective_function, np.zeros(4),0.5,restarts=5)

        
    def act(self, state):
        """
        Acts given an observation of the environment (using learned policy).

        Takes as argument an observation of the current state, and
        returns the chosen action.
        See environment documentation: https://github.com/openai/gym/wiki/MountainCar-v0
        Possible action: [0, 1, 2, 3]
        
        """
        return np.argmax(np.dot(state,self.policy_opt.reshape(2,2)))
        #return np.random.choice([0, 1, 2, 3])

# %%
agent = Agent()
agent.train()
# Out:
# (4_w,8)-aCMA-ES (mu_w=2.6,w_1=52%) in dimension 4 (seed=158166, Sun Jan 31 17:11:18 2021)
# target reached
# ------------> 628 0
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      8 4.000000000000000e+00 1.0e+00 4.40e-01  4e-01  4e-01 0:00.2
#     2     16 2.000000000000000e+02 1.4e+00 5.34e-01  4e-01  7e-01 0:00.2
# target reached
# ------------> 659 3
#     3     24 9.000000000000000e+00 1.8e+00 5.62e-01  4e-01  7e-01 0:00.3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 1
# target reached
# ------------> 628 0
# target reached
# ------------> 661 3
# target reached
# ------------> 691 1
#    10     80 2.000000000000000e+02 3.7e+00 6.87e-01  5e-01  1e+00 0:00.5
# termination on tolflatfitness=1 (Sun Jan 31 17:11:18 2021)
# final/bestever f-value = 2.000000e+02 1.000000e+00
# incumbent solution: [-1.2750588875592592, 0.03337001739146628, -0.4202057415283743, -0.5167662946012762]
# std deviation: [0.6939788568252988, 0.5190511098706886, 0.6894497682428856, 1.2737096934990317]
# (8_w,16)-aCMA-ES (mu_w=4.8,w_1=32%) in dimension 4 (seed=158167, Sun Jan 31 17:11:18 2021)
# target reached
# ------------> 629 0
# target reached
# ------------> 691 1
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     97 5.000000000000000e+00 1.0e+00 4.19e-01  4e-01  4e-01 0:00.1
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
#     2    113 1.000000000000000e+01 1.3e+00 5.08e-01  4e-01  6e-01 0:00.2
#     3    129 2.000000000000000e+02 1.6e+00 5.17e-01  4e-01  6e-01 0:00.2
#     4    145 2.000000000000000e+02 1.6e+00 5.19e-01  4e-01  5e-01 0:00.3
# termination on tolflatfitness=1 after 1 restart (Sun Jan 31 17:11:19 2021)
# final/bestever f-value = 2.000000e+02 1.000000e+00
# incumbent solution: [0.5634900523737347, -0.17211204892596293, -0.5539913539723044, -0.16783085141130932]
# std deviation: [0.537562343330294, 0.4676306787461569, 0.4318525517799801, 0.46294249801122545]
# (16_w,32)-aCMA-ES (mu_w=9.2,w_1=19%) in dimension 4 (seed=158168, Sun Jan 31 17:11:19 2021)
# target reached
# ------------> 691 1
# target reached
# ------------> 691 3
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1    178 1.000000000000000e+00 1.0e+00 5.15e-01  5e-01  5e-01 0:00.2
# target reached
# ------------> 691 3
# target reached
# ------------> 693 2
#     2    210 4.000000000000000e+00 1.4e+00 5.70e-01  5e-01  7e-01 0:00.3
# target reached
# ------------> 629 2
# target reached
# ------------> 693 2
#     3    242 4.000000000000000e+00 1.9e+00 5.45e-01  4e-01  7e-01 0:00.6
# target reached
# ------------> 691 3
# target reached
# ------------> 661 2
# target reached
# ------------> 659 3
# target reached
# ------------> 628 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 2
# target reached
# ------------> 693 2
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 2
# target reached
# ------------> 693 2
# target reached
# ------------> 661 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 691 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 661 2
# target reached
# ------------> 627 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 693 2
# target reached
# ------------> 628 0
# target reached
# ------------> 693 2
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
#    22    850 4.000000000000000e+00 5.0e+00 2.30e-01  1e-01  1e-01 0:03.6
# target reached
# ------------> 629 0
# target reached
# ------------> 692 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 2
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 661 2
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 693 1
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 692 1
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 1
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 1
#    48   1682 1.000000000000000e+00 3.5e+01 2.26e-01  9e-02  2e-01 0:07.6
# target reached
# ------------> 660 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 2
# target reached
# ------------> 629 0
# target reached
# ------------> 691 1
# target reached
# ------------> 693 1
# target reached
# ------------> 693 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 692 0
# target reached
# ------------> 628 1
# target reached
# ------------> 627 0
# target reached
# ------------> 693 2
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 1
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 1
# target reached
# ------------> 693 1
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 693 1
# target reached
# ------------> 691 1
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 693 1
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 692 1
# target reached
# ------------> 628 0
# target reached
# ------------> 691 1
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 692 0
# target reached
# ------------> 661 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 1
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 661 2
# target reached
# ------------> 627 0
# target reached
# ------------> 691 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 661 0
# target reached
# ------------> 627 0
#    83   2802 1.000000000000000e+00 3.3e+01 1.82e-01  2e-02  6e-02 0:12.6
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 661 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 660 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
#   100   3346 1.200000000000000e+01 2.9e+01 1.57e-01  1e-02  3e-02 0:14.8
# target reached
# ------------> 691 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 661 2
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 659 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 661 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 661 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 692 0
# target reached
# ------------> 627 0
# target reached
# ------------> 692 0
# target reached
# ------------> 628 0
# target reached
# ------------> 659 0
# target reached
# ------------> 660 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 660 0
# target reached
# ------------> 659 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 660 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
#   154   5074 3.000000000000000e+00 1.1e+02 3.94e-02  9e-04  5e-03 0:21.8
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 659 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 660 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 661 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 692 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 0
# target reached
# ------------> 628 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 693 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 660 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 659 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
#   200   6546 1.000000000000000e+00 8.1e+01 5.40e-02  5e-04  2e-03 0:29.0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 693 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 660 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 660 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 691 0
# target reached
# ------------> 661 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 661 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 660 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 660 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
#   261   8498 1.200000000000000e+01 6.7e+02 6.02e-02  3e-04  2e-03 0:38.0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 660 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
#   287   9330 2.000000000000000e+02 3.5e+03 1.24e-01  1e-03  7e-03 0:41.6
# termination on tolflatfitness=1 after 2 restarts (Sun Jan 31 17:12:02 2021)
# final/bestever f-value = 2.000000e+02 1.000000e+00
# incumbent solution: [0.24948631449103767, 0.18513184182206252, 0.16927908433009334, -0.15199222600719947]
# std deviation: [0.0018224871325525438, 0.0010724613973554886, 0.0074579096362159475, 0.006578131836231776]
# (32_w,64)-aCMA-ES (mu_w=17.6,w_1=11%) in dimension 4 (seed=158169, Sun Jan 31 17:12:02 2021)
# target reached
# ------------> 693 2
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1   9395 1.000000000000000e+00 1.0e+00 5.20e-01  5e-01  6e-01 0:00.3
# target reached
# ------------> 629 2
# target reached
# ------------> 693 2
# target reached
# ------------> 693 1
#     2   9459 2.000000000000000e+00 1.4e+00 5.56e-01  6e-01  7e-01 0:00.6
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 628 0
#     3   9523 1.000000000000000e+00 1.9e+00 6.34e-01  7e-01  8e-01 0:00.9
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 693 1
# target reached
# ------------> 627 3
# target reached
# ------------> 693 1
# target reached
# ------------> 691 3
# target reached
# ------------> 692 1
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 629 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 692 1
# target reached
# ------------> 661 2
# target reached
# ------------> 659 3
# target reached
# ------------> 692 1
# target reached
# ------------> 627 3
# target reached
# ------------> 659 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 0
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 661 2
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 693 2
# target reached
# ------------> 660 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
#    15  10291 1.000000000000000e+01 5.8e+00 8.39e-01  8e-01  1e+00 0:04.1
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 628 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 693 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 628 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 2
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 629 2
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 2
# target reached
# ------------> 691 3
#    29  11187 1.300000000000000e+01 4.1e+01 8.34e-01  1e+00  2e+00 0:08.5
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 693 2
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 661 2
# target reached
# ------------> 659 3
# target reached
# ------------> 693 2
# target reached
# ------------> 627 3
# target reached
# ------------> 660 3
# target reached
# ------------> 691 3
# target reached
# ------------> 660 1
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 693 2
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 661 2
# target reached
# ------------> 627 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 692 2
# target reached
# ------------> 693 2
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 692 1
# target reached
# ------------> 693 2
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 629 3
# target reached
# ------------> 661 2
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 2
# target reached
# ------------> 629 2
# target reached
# ------------> 661 2
# target reached
# ------------> 661 2
# target reached
# ------------> 627 3
# target reached
# ------------> 661 2
# target reached
# ------------> 627 3
#    47  12339 1.000000000000000e+00 5.9e+01 5.40e-01  3e-01  5e-01 0:13.8
# target reached
# ------------> 661 2
# target reached
# ------------> 691 3
# target reached
# ------------> 629 2
# target reached
# ------------> 693 2
# target reached
# ------------> 629 2
# target reached
# ------------> 661 2
# target reached
# ------------> 629 2
# target reached
# ------------> 627 3
# target reached
# ------------> 660 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 2
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 660 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 661 2
# target reached
# ------------> 693 3
# target reached
# ------------> 691 3
# target reached
# ------------> 628 2
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 660 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 661 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 628 3
# target reached
# ------------> 691 2
# target reached
# ------------> 661 2
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 661 2
# target reached
# ------------> 629 3
# target reached
# ------------> 692 2
# target reached
# ------------> 691 3
# target reached
# ------------> 627 2
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
#    67  13619 9.000000000000000e+00 3.8e+02 6.16e-01  6e-01  1e+00 0:19.9
# target reached
# ------------> 693 2
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 660 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 629 2
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 628 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 692 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 660 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 628 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 2
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 660 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 692 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 629 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
#    92  15219 5.000000000000000e+00 8.5e+02 4.26e-01  3e-01  6e-01 0:26.9
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 660 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 661 2
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 2
# target reached
# ------------> 693 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 661 2
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
#   100  15731 8.000000000000000e+00 1.8e+03 3.11e-01  2e-01  4e-01 0:29.2
# target reached
# ------------> 629 2
# target reached
# ------------> 691 3
# target reached
# ------------> 693 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 660 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 693 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 692 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 660 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 2
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 2
# target reached
# ------------> 659 3
# target reached
# ------------> 629 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 693 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 693 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 629 3
# target reached
# ------------> 693 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 661 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 660 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
#   129  17587 1.000000000000000e+00 6.1e+03 2.92e-01  8e-02  2e-01 0:38.2
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 692 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 660 3
# target reached
# ------------> 627 3
# target reached
# ------------> 661 3
# target reached
# ------------> 628 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 628 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 629 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 661 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 693 3
# target reached
# ------------> 627 3
# target reached
# ------------> 693 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 660 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 692 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 661 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
#   163  19763 2.000000000000000e+02 4.0e+03 8.93e-01  9e-02  2e-01 0:48.4
# target reached
# ------------> 661 3
# target reached
# ------------> 692 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 629 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 660 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# ...
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 628 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 628 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
#   231  71220 1.000000000000000e+00 4.4e+04 1.04e+00  1e-02  2e-02 2:14.5
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 629 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
# target reached
# ------------> 628 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 693 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 661 3
# target reached
# ------------> 660 3
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 3
# target reached
# ------------> 627 3
# target reached
# ------------> 691 3
#   238  72116 1.000000000000000e+00 3.5e+04 1.01e+00  7e-03  2e-02 2:18.3
# termination on tolfunhist=1e-12 after 4 restarts (Sun Jan 31 17:16:53 2021)
# final/bestever f-value = 2.000000e+02 1.000000e+00
# incumbent solution: [0.7865974714253535, 0.07716521623827514, -0.23045516096951799, 1.263217708852276]
# std deviation: [0.01019256154070138, 0.015459352674690075, 0.006973907081332648, 0.009983432732598257]
# (128_w,256)-aCMA-ES (mu_w=66.9,w_1=3%) in dimension 4 (seed=158171, Sun Jan 31 17:16:53 2021)
# target reached
# ------------> 693 1
# target reached
# ------------> 627 2
# target reached
# ------------> 693 2
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 692 1
# target reached
# ------------> 629 2
# target reached
# ------------> 627 0
# target reached
# ------------> 692 1
# target reached
# ------------> 627 0
# target reached
# ------------> 628 2
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1  72373 1.000000000000000e+00 1.0e+00 4.85e-01  4e-01  5e-01 0:01.1
# target reached
# ------------> 628 0
# target reached
# ------------> 693 2
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 627 0
# target reached
# ------------> 693 2
# target reached
# ------------> 692 1
# target reached
# ------------> 629 2
# target reached
# ------------> 691 3
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
#     2  72629 1.000000000000000e+00 1.4e+00 5.01e-01  4e-01  6e-01 0:02.2
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 691 1
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 692 1
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 1
# target reached
# ------------> 693 1
# target reached
# ------------> 693 1
# target reached
# ------------> 627 0
#     3  72885 1.000000000000000e+00 1.7e+00 5.13e-01  4e-01  6e-01 0:03.3
# target reached
# ------------> 659 3
# target reached
# ------------> 693 3
# target reached
# ------------> 693 1
# target reached
# ------------> 629 0
# target reached
# ------------> 660 2
# target reached
# ------------> 691 1
# target reached
# ------------> 629 0
# target reached
# ------------> 659 3
# target reached
# ------------> 692 1
# target reached
# ------------> 660 3
# target reached
# ------------> 692 1
# target reached
# ------------> 627 0
# target reached
# ------------> 692 1
# target reached
# ------------> 629 2
# target reached
# ------------> 693 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 3
# target reached
# ------------> 659 3
# target reached
# ------------> 659 3
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 691 1
# target reached
# ------------> 693 0
# target reached
# ------------> 659 3
# target reached
# ------------> 693 2
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 692 1
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 2
# target reached
# ------------> 659 3
# target reached
# ------------> 691 3
# target reached
# ------------> 691 3
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
#     6  73653 2.000000000000000e+00 1.9e+00 5.52e-01  4e-01  6e-01 0:06.4
# target reached
# ------------> 659 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 1
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 660 1
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 2
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 691 1
# target reached
# ------------> 692 1
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 661 1
# target reached
# ------------> 629 0
# target reached
# ------------> 692 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 3
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 660 0
# target reached
# ------------> 627 0
# target reached
# ------------> 661 0
# target reached
# ------------> 691 3
# target reached
# ------------> 627 0
# target reached
# ------------> 691 1
# target reached
# ------------> 627 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 691 1
# target reached
# ------------> 659 3
# target reached
# ------------> 693 1
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 693 1
# target reached
# ------------> 627 0
# target reached
# ------------> 691 1
# target reached
# ------------> 661 2
# target reached
# ------------> 661 2
# target reached
# ------------> 627 0
# target reached
# ------------> 628 3
#    10  74677 1.000000000000000e+00 2.9e+00 5.66e-01  4e-01  7e-01 0:10.8
# target reached
# ------------> 659 3
# target reached
# ------------> 692 1
# target reached
# ------------> 628 0
# target reached
# ------------> 691 1
# target reached
# ------------> 629 0
# target reached
# ------------> 691 1
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 693 2
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 3
# target reached
# ------------> 627 3
# target reached
# ------------> 660 0
# target reached
# ------------> 691 0
# target reached
# ------------> 628 0
# target reached
# ------------> 693 2
# target reached
# ------------> 628 0
# target reached
# ------------> 661 2
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 693 2
# target reached
# ------------> 628 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 692 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 3
# target reached
# ------------> 659 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 659 0
# target reached
# ------------> 659 0
# target reached
# ------------> 628 3
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 1
# target reached
# ------------> 691 3
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
#    14  75701 1.000000000000000e+00 4.4e+00 5.07e-01  3e-01  6e-01 0:16.2
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 693 2
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 3
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 661 2
# target reached
# ------------> 629 0
# target reached
# ------------> 692 1
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 692 0
# target reached
# ------------> 691 1
# target reached
# ------------> 628 0
# target reached
# ------------> 659 0
# target reached
# ------------> 693 2
# target reached
# ------------> 692 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 691 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 2
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 660 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 693 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 659 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 691 2
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
#    20  77237 1.000000000000000e+00 6.2e+00 4.26e-01  2e-01  5e-01 0:22.7
# target reached
# ------------> 661 2
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 692 0
# target reached
# ------------> 693 2
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 629 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 661 0
# target reached
# ------------> 628 0
# target reached
# ------------> 659 2
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
# target reached
# ------------> 627 0
# target reached
# ------------> 628 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 628 0
# target reached
# ------------> 629 0
# target reached
# ------------> 627 0
#    22  77749 1.000000000000000e+00 5.8e+00 3.85e-01  2e-01  5e-01 0:25.5
# termination on tolfunhist=1e-12 after 5 restarts (Sun Jan 31 17:17:19 2021)
# final/bestever f-value = 2.000000e+02 1.000000e+00
# incumbent solution: [0.947667545292316, 0.12773944932742962, -0.11808032622373466, -0.10090521197364559]
# std deviation: [0.4612103137656206, 0.36675867080286917, 0.3440350711351795, 0.1870736767279482]

# %% [markdown]
# ### Testing
#
# Run simulation to test your trained agent.

# %%
niter = 5000

# %%
env = gym.make("Pendulum-v0").env
env.seed(np.random.randint(1, 1000))
env.reset()
i=1
try:
    for i in range(1,niter+1):
        sys.stdout.flush()
        action = agent.act(env.state)
        state, reward, done, info = env.step(action)
        print("state",state,"reward",reward,"action",action,"niter",i)

        # update the visualization
        env.render()
        print("here1")
        i=i+1

        # check for rewards
        if (state >=561 and state<=759):
            print("\rTop reached at t = {}".format(_))
            break
        elif  _ == niter:
            print("\rFailed to reach the top")
       # print("niter==",niter)
finally:
    print("close env")
# Out:
# state 740 reward 0 action 2 niter 1
# x,y 115 20
# here1
# Top reached at t =
# close env

# %%
env.close()
